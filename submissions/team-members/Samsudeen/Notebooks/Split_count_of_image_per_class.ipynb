# %%
import os
from collections import defaultdict

base_dir = "C:/Users/OWNER/Downloads/SDS-CP028-smart-leaf/submissions/team-members/Samsudeen/TrainValTestDir"

split_counts = defaultdict(dict)

for split in ['train', 'val', 'test']:
    split_path = os.path.join(base_dir, split)
    print(f"\n📁 {split.upper()}:")

    for class_name in sorted(os.listdir(split_path)):
        class_path = os.path.join(split_path, class_name)
        if not os.path.isdir(class_path):
            continue

        count = len([
            f for f in os.listdir(class_path)
            if os.path.isfile(os.path.join(class_path, f))
        ])

        split_counts[split][class_name] = count
        print(f"  {class_name}: {count} images")

# Optional: Summary
print("\n📊 Summary Totals:")
for split in ['train', 'val', 'test']:
    total = sum(split_counts[split].values())
    print(f"  {split}: {total} images")
# Out:
# 📁 TRAIN:
#   Corn___Common_Rust: 953 images
#   Corn___Gray_Leaf_Spot: 841 images
#   Corn___Healthy: 929 images
#   Corn___Northern_Leaf_Blight: 850 images
#   Potato___Early_Blight: 850 images
#   Potato___Healthy: 817 images
#   Potato___Late_Blight: 850 images
#   Rice___Brown_Spot: 846 images
#   Rice___Healthy: 1190 images
#   Rice___Leaf_Blast: 850 images
#   Rice___Neck_Blast: 849 images
#   Wheat___Brown_Rust: 849 images
#   Wheat___Healthy: 892 images
#   Wheat___Yellow_Rust: 850 images
#
# 📁 VAL:
#   Corn___Common_Rust: 119 images
#   Corn___Gray_Leaf_Spot: 51 images
#   Corn___Healthy: 116 images
#   Corn___Northern_Leaf_Blight: 98 images
#   Potato___Early_Blight: 100 images
#   Potato___Healthy: 15 images
#   Potato___Late_Blight: 100 images
#   Rice___Brown_Spot: 61 images
#   Rice___Healthy: 148 images
#   Rice___Leaf_Blast: 97 images
#   Rice___Neck_Blast: 100 images
#   Wheat___Brown_Rust: 90 images
#   Wheat___Healthy: 111 images
#   Wheat___Yellow_Rust: 92 images
#
# 📁 TEST:
#   Corn___Common_Rust: 120 images
#   Corn___Gray_Leaf_Spot: 52 images
#   Corn___Healthy: 117 images
#   Corn___Northern_Leaf_Blight: 99 images
#   Potato___Early_Blight: 100 images
#   Potato___Healthy: 16 images
#   Potato___Late_Blight: 100 images
#   Rice___Brown_Spot: 62 images
#   Rice___Healthy: 150 images
#   Rice___Leaf_Blast: 99 images
#   Rice___Neck_Blast: 100 images
#   Wheat___Brown_Rust: 91 images
#   Wheat___Healthy: 113 images
#   Wheat___Yellow_Rust: 93 images
#
# 📊 Summary Totals:
#   train: 12416 images
#   val: 1298 images
#   test: 1312 images
